# %%
import pandas as pd                        #Importing the esential libraries
import numpy as np

# %%
df= pd.read_excel('C:\\Users\\Anjali\\notebooks\\Untitled Folder\\HIV_0000000006.xlsx')

# %%
df               #reading the dataset
# Out:
#           WHO region  Year Number of deaths due to HIV/AIDS
# 0             Global  2019        690 000 [500 000–970 000]
# 1             Global  2018      730 000 [530 000–1 000 000]
# 2             Global  2017      760 000 [550 000–1 100 000]
# 3             Global  2016      800 000 [580 000–1 100 000]
# 4             Global  2015      830 000 [610 000–1 200 000]
# ..               ...   ...                              ...
# 205  Western Pacific  1994               7700 [4100–13 000]
# 206  Western Pacific  1993                 5500 [2900–9500]
# 207  Western Pacific  1992                 4000 [2100–6800]
# 208  Western Pacific  1991                 2900 [1600–5000]
# 209  Western Pacific  1990                 2100 [1100–3600]
#
# [210 rows x 3 columns]

# %%
df.columns                     #viweing the total number of columns in a datset
# Out:
# Index(['WHO region', 'Year', 'Number of deaths due to HIV/AIDS'], dtype='object')

# %% [raw]
#    Removing the Brackets AND Value inside Brackets  of the dataset

# %%
df['Number of deaths due to HIV/AIDS']=df['Number of deaths due to HIV/AIDS'].str.replace(r"\[.*\]","")     
df['Number of deaths due to HIV/AIDS']=df['Number of deaths due to HIV/AIDS'].str.replace(r"\ &lt ","")

# %% [raw]
#  RESULTANT DATASET

# %%
df
# Out:
#           WHO region  Year Number of deaths due to HIV/AIDS
# 0             Global  2019                         690 000
# 1             Global  2018                         730 000
# 2             Global  2017                         760 000
# 3             Global  2016                         800 000
# 4             Global  2015                         830 000
# ..               ...   ...                              ...
# 205  Western Pacific  1994                            7700
# 206  Western Pacific  1993                            5500
# 207  Western Pacific  1992                            4000
# 208  Western Pacific  1991                            2900
# 209  Western Pacific  1990                            2100
#
# [210 rows x 3 columns]

# %% [markdown]
# # Exporting the cleaned datasets to excel

# %%
df.to_excel('C:\\Users\\Anjali\\notebooks\\Untitled Folder\\HIV cleaned 1.xlsx',index= False , header= True)   #dataset exported to excel file

# %% [markdown]
# # Removal of brackets from another dataset

# %%
df= pd.read_excel('C:\\Users\\Anjali\\notebooks\\Untitled Folder\\HIV_0000000026,SDGHIV (1).xlsx')

# %%
df             #reading of the dataset
# Out:
#           Unnamed: 0 Unnamed: 1     Number of new HIV infections  \
# 0         WHO region       Year
# 1             Global       2019  1 700 000 [1 200 000–2 200 000]
# 2             Global       2018  1 700 000 [1 200 000–2 300 000]
# 3             Global       2017  1 800 000 [1 300 000–2 400 000]
# 4             Global       2016  1 800 000 [1 300 000–2 400 000]
# ..               ...        ...                              ...
# 206  Western Pacific       1994         140 000 [87 000–180 000]
# 207  Western Pacific       1993           50 000 [32 000–67 000]
# 208  Western Pacific       1992           40 000 [25 000–53 000]
# 209  Western Pacific       1991           30 000 [19 000–40 000]
# 210  Western Pacific       1990           23 000 [14 000–31 000]
#
#     New HIV infections (per 1000 uninfected population)  \
# 0                                           Both sexes
# 1                                      0.22 [0.16–0.3]
# ...

# %%
df.columns              # viweing the total number of columns present in a dataset
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Number of new HIV infections',
#        'New HIV infections (per 1000 uninfected population)',
#        'New HIV infections (per 1000 uninfected population).1',
#        'New HIV infections (per 1000 uninfected population).2'],
#       dtype='object')

# %%
df[ 'New HIV infections (per 1000 uninfected population)']=df[ 'New HIV infections (per 1000 uninfected population)'].str.replace(r"\[.*\]","")

# %%
df['New HIV infections (per 1000 uninfected population).1']=df['New HIV infections (per 1000 uninfected population).1'].str.replace(r"\[.*\]","")

# %%
df['New HIV infections (per 1000 uninfected population).2']=df['New HIV infections (per 1000 uninfected population).2'].str.replace(r"\[.*\]","")

# %%
df['Number of new HIV infections']=df['Number of new HIV infections'].str.replace(r"\[.*\]","")

# %%
df['New HIV infections (per 1000 uninfected population).2']=df['New HIV infections (per 1000 uninfected population).2'].str.replace(r"\&lt","")

# %%
#renaming drithe columns
df.rename(columns={'Unnamed: 0':'WHO region', 'Unnamed: 1':'Year'}, inplace = True)

# %% [raw]
#     RESULTANT DATASET

# %%
df
# Out:
#           WHO region  Year Number of new HIV infections  \
# 0         WHO region  Year
# 1             Global  2019                   1 700 000
# 2             Global  2018                   1 700 000
# 3             Global  2017                   1 800 000
# 4             Global  2016                   1 800 000
# ..               ...   ...                          ...
# 206  Western Pacific  1994                     140 000
# 207  Western Pacific  1993                      50 000
# 208  Western Pacific  1992                      40 000
# 209  Western Pacific  1991                      30 000
# 210  Western Pacific  1990                      23 000
#
#     New HIV infections (per 1000 uninfected population)  \
# 0                                           Both sexes
# 1                                                0.22
# 2                                                0.23
# 3                                                0.24
# ...

# %% [markdown]
# # Exporting the cleaned datasets to excel

# %%
df1.to_excel('C:\\Users\\Anjali\\notebooks\\Untitled Folder\\HIV1.xlsx',index= False , header= True)   #dataset exported to excel file

# %%
df1
# Out:
#           WHO region  Year Number of new HIV infections  \
# 1             Global  2019                   1 700 000
# 2             Global  2018                   1 700 000
# 3             Global  2017                   1 800 000
# 4             Global  2016                   1 800 000
# 5             Global  2015                   1 900 000
# ..               ...   ...                          ...
# 206  Western Pacific  1994                     140 000
# 207  Western Pacific  1993                      50 000
# 208  Western Pacific  1992                      40 000
# 209  Western Pacific  1991                      30 000
# 210  Western Pacific  1990                      23 000
#
#     New HIV infections (per 1000 uninfected population)  \
# 1                                                0.22
# 2                                                0.23
# 3                                                0.24
# 4                                                0.25
# ...
